# %%
import galsim
import batsim.transforms
import batsim.stamp
import numpy as np
import numpy.lib.recfunctions as rfn
import matplotlib.pyplot as plt
import fpfs

from tqdm import tqdm, trange
from scipy.optimize import curve_fit

# %%
cosmos = galsim.COSMOSCatalog()

bigfft = galsim.GSParams(maximum_fft_size=20000)  # galsim setup

index = 1
galaxy = cosmos.makeGalaxy(index=index, gal_type='parametric', noise_pad_size=0, rng=None, gsparams=bigfft)
rec = cosmos.getParametricRecord(index=index)
print(rec['hlr'], rec['flux'])
hlr = galaxy.calculateHLR()
print(galaxy.original.half_light_radius)
print(hlr)
r_sec = galaxy.calculateMomentRadius()
print(r_sec)
cosmax = 81499
# Out:
# [0.09744617 0.         0.        ] [2.69986838 0.         0.         0.        ]
# 0.0974461731996633
# 0.1292750476830385
# 0.16867294133165206

# %%
def cancel_shape_noise(gal_obj, nrot):

    rotated_gals = []
    for i in range(nrot):
        rot_ang = np.pi / nrot * i
        ang = rot_ang * galsim.radians
        gal_obj = gal_obj.rotate(ang)
        rotated_gals.append(gal_obj)
        
    return rotated_gals

rotated_gals = cancel_shape_noise(galaxy, 4)

nn = 128
scale = 0.01
plt.subplots(1, 5, figsize=(15, 3))
for i in range(4):
    plt.subplot(1, 5, i+1)
    plt.imshow(rotated_gals[i].drawImage(nx=nn, ny=nn, scale=scale).array)
    plt.axis('off')

plt.subplot(1, 5, 5)
plt.imshow(np.sum([gal.drawImage(nx=nn, ny=nn, scale=scale).array for gal in rotated_gals], axis=0))

# %% [markdown]
# ### Maybe this above very involved process isn't needed? - Lets see if we can just use the disk HLR?
# - turns out I'm a muppet and all the disk+bulge galaxies have a total hlr measurment

# %%
rec = cosmos.getParametricRecord(index=np.arange(cosmax))
sersic_mask = rec['use_bulgefit'].astype(bool)
inverted_mask = ~np.array(sersic_mask)

disk_hlr = rec['hlr'][sersic_mask][:, 0]
bulge_hlr = rec['hlr'][sersic_mask][:, 1]
total_hlr = rec['hlr'][sersic_mask][:, 2]
print('N_b+d:',len(total_hlr))

sersic_hlr = rec['hlr'][inverted_mask][:,0]
print('N_sersic:',len(sersic_hlr))

plt.hist(disk_hlr, bins=100, histtype='step', label='disk', range=(0, 0.5), density=True);
plt.hist(bulge_hlr, bins=100, histtype='step', label='bulge', range=(0, 0.5), density=True);
plt.hist(sersic_hlr, bins=100, histtype='step', label='sersic', range=(0, 0.5), density=True);
plt.hist(total_hlr, bins=100, histtype='step', label='disk+bulge', range=(0, 0.5), density=True);
plt.xlabel('HLR')
plt.ylabel('Density')
plt.legend()
# Out:
# N_b+d: 23425
# N_sersic: 58074

# %% [markdown]
# ### Convolve all galaxies with an LSST-esq PSF to see what the distribution of observed sizes is like

# %%
# LSST Specifications
diameter = 8.4  # meters
effective_diameter = 6.423  # meters, area weighted
seeing = 0.67  # arcseconds

AtmosphericPSF = galsim.Kolmogorov(fwhm=seeing, flux=1.0, gsparams=bigfft)
OpticalPSF = galsim.OpticalPSF(lam=500, diam=effective_diameter, obscuration=effective_diameter/diameter)

TotPSF = galsim.Convolve([AtmosphericPSF, OpticalPSF])
#TotPSF = galsim.Moffat(beta=3.5, fwhm=0.6, trunc=0.6 * 4.0).shear(e1=0.02, e2=-0.02)

galaxies = cosmos.makeGalaxy(index=np.arange(cosmax), gal_type='parametric', noise_pad_size=0, rng=None, gsparams=bigfft)

# %%
mask_sersic = rec['use_bulgefit'].astype(bool)
mask_bd = ~np.array(mask_sersic)

bd_hlrs = rec['hlr'][:, 2] * mask_sersic
sersic_hlrs = rec['hlr'][:, 0] * mask_bd

all_hlrs = bd_hlrs + sersic_hlrs

# %%
r_sec = np.load('cosmos_r_sec.npz')['arr_0']
failed = np.where(r_sec == -1)[0]
print(len(failed))
#print(all_hlrs[failed])

# Define the function to fit
def parameterization(x, a, b, c):
    return a * np.exp(-b * x) + c

# Define the histogram data
hist, bins = np.histogram(all_hlrs, bins=100, range=(0, 1.25), density=True)
x = (bins[:-1] + bins[1:]) / 2

# Fit the parameterization to the histogram data
popt, pcov = curve_fit(parameterization, x, hist)

# Generate the fitted curve
x_fit = np.linspace(0, 1.25, 100)
lsst_fit = parameterization(x_fit, a=9.2, b=3.2, c=-0.05)
cosmos_fit = parameterization(x_fit, a=popt[0], b=popt[1], c=popt[2])

# Plot the histogram and the fitted curve
plt.hist(all_hlrs, bins=100, histtype='step', range=(0, 1.25), density=True, label='r_hlr')
plt.hist(r_sec, bins=100, histtype='step', range=(0, 1.25), density=True, label='r_sec')
plt.plot(x_fit, lsst_fit, 'r-', label='LSST SRD fit')
plt.plot(x_fit, cosmos_fit, 'g--', label='COSMOS fit')
plt.xlabel('radius [arcsec]')
plt.ylabel('Density')
plt.legend()
plt.show()

# Print the fitted parameters
print('Fitted Parameters:')
print('a:', popt[0])
print('b:', popt[1])
print('c:', popt[2])
# Out:
# 5625
# Fitted Parameters:
# a: 3.8166483354047958
# b: 1.1325019716424445
# c: -1.2415285492031463

# %% [markdown]
# The LSST SRD defines r_sec = root(2) * sigma_p. The red line is a parametic fit to the distribution of r_sec for the WLD galaxies. If we pressume sigma_p = hlr and take the cosmos half light radii, multiply them all by 1.25 and then conver them as before to r_sec, we get a distribution that closely approximates that of the LSST SRD galaxies.

# %% [markdown]
# ### NEED TO CHECK I CAN USE THESE EQUATIONS GENERICALLY!!!

# %%
# get effective size as per the definition of Chang et al. 2013

def calculate_effective_size(r_sec, r_PSF=0.67):
    # calculate effective size as per the definition of Chang et al. 2013
    # https://arxiv.org/pdf/1308.5170.pdf
    R_gals = r_sec**2 / r_PSF**2

    return R_gals

R_gals = calculate_effective_size(r_sec)

# %%
plt.hist(R_gals, bins=100, histtype='step', range=(0, 3), density=True);
plt.xlabel('R_effective')
plt.ylabel('Density')

R_1_5 = R_gals[R_gals > 1.5]
R_2  = R_gals[R_gals > 2.0]
R_3 = R_gals[R_gals > 3.0]
print(len(R_1_5), len(R_2), len(R_3))
# Out:
# 10988 9695 2726

# %% [markdown]
# Using the rescaling defined earlier, we get a distribution of effective size very similar to that of the LSST SRD, with an LSST-like PSF

# %% [markdown]
# ### Ok, so lets try generate a few (1k) galaxies from cosmos
# - determine their effective size
# - rotate them to cancel noise
# - apply shear
# - convolve with PSF
# - measure shear

# %%
rng = galsim.BaseDeviate(14)
nrot = 4
ngal = 100

bigfft = galsim.GSParams(maximum_fft_size=60000)  # galsim setup

if ngal % nrot != 0:
    raise ValueError('ngal/nrot must be an integer')

inc = np.where([r_sec > 0.1])[0]
gal_sample = cosmos.makeGalaxy(gText(0.5, 1.0, 'Combined images')
￼
0.019997
￼
Maybe this above very involved process isn't needed? - Lets see if we can just use the disk HLR?
turns out I'm a muppet and all the disk+bulge galaxies have a total hlr measurment
Convolve all galaxies with an LSST-esq PSF to see what the distribution of observed sizes is like
The LSST SRD defines r_sec = root(2) * sigma_p. The red line is a parametic fit to the distribution of r_sec for the WLD galaxies. If we pressume sigma_p = hlr and take the cosmos half light radii, multiply them all by 1.25 and then conver them as before to r_sec, we get a distribution that closely approximates that of the LSST SRD galaxies.

NEED TO CHECK I CAN USE THESE EQUATIONS GENERICALLY!!!
Using the rescaling defined earlier, we get a distribution of effective size very similar to that of the LSST SRD, with an LSST-like PSF

Ok, so lets try generate a few (1k) galaxies from cosmos
determine their effective size
rotate them to cancel noise
apply shear
convolve with PSF
measure shear
Measure shear on full sample
Include detection of galaxies
Now lets look at the effect of using different shapelet kernel sizes in a constant shear case with FPFS handling detection
Final test: Add IA shear and see how we perform
[0.09744617 0.         0.        ] [2.69986838 0.         0.         0.        ]
0.0974461731996633
0.1292750476830385
0.16867294133165206
<matplotlib.image.AxesImage at 0x7fcf94ab1310>
￼
N_b+d: 23425
N_sersic: 58074
<matplotlib.legend.Legend at 0x7fcf9355ded0>
￼
5625
￼
Fitted Parameters:
a: 3.8166483354047958
b: 1.1325019716424445
c: -1.2415285492031463
10988 9695 2726
￼
71022al_type='parametric', noise_pad_size=0, index=inc)
print(len(gal_sample))

gal_sample_cancelled = [] 
for gal in gal_sample:
    rotated_gals = cancel_shape_noise(gal, nrot=4)
    shear_gals = [rotg.shear(g1=0.02) for rotg in rotated_gals]
    conv_gals = [galsim.Convolve([shearg, TotPSF]) for shearg in shear_gals]
    [gal_sample_cancelled.append(convg) for convg in conv_gals]
# Out:
# 71022

# %%
nn = 64
scale = 0.168
plt.subplots(1, 5, figsize=(15, 3))

gmin = 60
gmax = gmin+4

for i in range(4):
    plt.subplot(1, 5, i+1)
    plt.imshow(gal_sample_cancelled[gmin:gmax][i].drawImage(nx=nn, ny=nn, scale=scale).array, cmap='gray')
    plt.axis('off')
    plt.title('Rotation %d'%(i+1))

plt.subplot(1, 5, 5)
plt.imshow(np.sum([gal.drawImage(nx=nn, ny=nn, scale=scale).array for gal in gal_sample_cancelled[gmin:gmax]], axis=0), cmap='gray')
plt.axis('off')
plt.title('Combined images')
# Out:
# Text(0.5, 1.0, 'Combined images')

# %% [markdown]
# ## Now we should have 1000 galaxies with cancelling shape noise
# - So we try detect and measure the shear

# %% [markdown]
# #### Measure shear on individual galaxy

# %%
# gal = cosmos.makeGalaxy(index=2, gal_type='parametric', noise_pad_size=0, rng=None, gsparams=bigfft)
gal = gal_sample[0]
rotated_gals = cancel_shape_noise(gal, nrot=4)

true_shear = 0.02

sheared_gals = []
for gal in rotated_gals:
    gal_shear = gal.shear(g1=true_shear)
    gal_conv = galsim.Convolve([gal_shear, TotPSF])
    sheared_gals.append(gal_conv)

psf_arr = TotPSF.shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale).array

gal_arr = sheared_gals[0].shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale).array
for i in range(1, 4):
    next_arr = sheared_gals[i].shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale).array
    gal_arr = np.concatenate([gal_arr, next_arr], axis=1)

plt.imshow(gal_arr, cmap='gray')

fpTask = fpfs.image.measure_source(psf_arr, sigma_arcsec=0.7, pix_scale=scale)

rcut = nn/2
indX = np.arange(int(nn/2), nn*4, nn)
indY = np.arange(int(nn/2), nn, nn)
inds = np.meshgrid(indY, indX, indexing="ij")
coords = np.vstack([np.ravel(_) for _ in inds]).T

# measure shear with FPFS
mms = fpTask.measure(gal_arr, coords)
mms = fpTask.get_results(mms)
ells = fpfs.catalog.fpfs_m2e(mms, const=2000)
resp = np.average(ells['fpfs_R1E'])
shear = np.average(ells['fpfs_e1'])/resp

print('%1.6f'%shear)
# Out:
# 0.019997

# %% [markdown]
# #### Measure shear on full sample

# %%
psf_arr = TotPSF.shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale).array

# initialize FPFS shear measurement task
fpTask = fpfs.image.measure_source(psf_arr, sigma_arcsec=0.7, pix_scale=scale)

all_mms = []
for i in trange(4):
    gal = gal_sample_cancelled[i]
    gal_arr = gal.shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale).array
    
    # Force detection at the stamp center point (ngrid//2, ngrid//2)
    rcut = nn/2
    indX = np.arange(int(nn/2), nn, nn)
    indY = np.arange(int(nn/2), nn, nn)
    inds = np.meshgrid(indY, indX, indexing="ij")
    coords = np.vstack([np.ravel(_) for _ in inds]).T

    # measure shear with FPFS on individual galaxies
    mms = fpTask.measure(gal_arr, coords)
    mms = fpTask.get_results(mms)
    all_mms.append(mms)

# combine all FPFS moments into single recarray
combined_mms = np.recarray((len(all_mms)), dtype=all_mms[0].dtype)
for i in range(len(all_mms)):
    combined_mms[i] = all_mms[i]

# convert momemnts to ellipticity estimates
ells = fpfs.catalog.fpfs_m2e(combined_mms, const=2000)
resp = np.average(ells['fpfs_R1E'])
shear = np.average(ells['fpfs_e1'])/resp

print('%1.6f'%shear)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# 100%|██████████| 4/4 [00:00<00:00,  6.17it/s]
# 0.019997

# %% [markdown]
# #### Include detection of galaxies

# %%
rcut = 16

psf_arr = TotPSF.shift(0.5*scale, 0.5*scale).drawImage(nx=rcut*2, ny=rcut*2, scale=scale).array

p1 = nn //2 - rcut
p2 = nn //2 - rcut
psf_arr2 = np.pad(psf_arr, ((p1, p1), (p2, p2)))

# initialize FPFS shear measurement task
fpTask = fpfs.image.measure_source(psf_arr, sigma_arcsec=0.52, pix_scale=scale)

all_mms = []
for i in trange(16):
    gal = gal_sample_cancelled[i]
    gal_arr = gal.shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale).array

    coords = fpTask.detect_sources(gal_arr,psf_arr2,thres=0.01,thres2=-0.00,)

    # measure shear with FPFS on individual galaxies
    mms = fpTask.measure(gal_arr, coords)
    mms = fpTask.get_results(mms)
    all_mms.append(mms)

# combine all FPFS moments into single recarray
combined_mms = np.recarray((len(all_mms)), dtype=all_mms[0].dtype)
for i in range(len(all_mms)):
    combined_mms[i] = all_mms[i]

# convert momemnts to ellipticity estimates
ells = fpfs.catalog.fpfs_m2e(combined_mms, const=2000)
resp = np.average(ells['fpfs_R1E'])
shear = np.average(ells['fpfs_e1'])/resp

print('%1.6f'%shear)
# Out:
# 100%|██████████| 16/16 [00:02<00:00,  6.06it/s]
# 0.019997

# %% [markdown]
# #### Now lets look at the effect of using different shapelet kernel sizes in a constant shear case with FPFS handling detection

# %%
def detect_and_measure(sigma_arcsec, psf_arr, gal_list, nn=64, scale=0.168, dn=0.5):

    # initialize FPFS shear measurement task
    fpTask = fpfs.image.measure_source(psf_arr, sigma_arcsec=sigma_arcsec, pix_scale=scale)

    p1 = nn //2 - rcut
    p2 = nn //2 - rcut
    psf_arr_pad = np.pad(psf_arr, ((p1, p1), (p2, p2)))

    all_mms = []
    for i in trange(len(gal_list)):
        gal = gal_list[i]
        gal_arr = gal.shift(dn*scale, dn*scale).drawImage(nx=nn, ny=nn, scale=scale).array

        coords = fpTask.detect_sources(gal_arr,psf_arr_pad,thres=0.01,thres2=-0.00,)

        # measure shear with FPFS on individual galaxies
        mms = fpTask.measure(gal_arr, coords)
        mms = fpTask.get_results(mms)
        all_mms.append(mms)

    # combine all FPFS moments into single recarray
    combined_mms = np.recarray((len(all_mms)), dtype=all_mms[0].dtype)
    for i in range(len(all_mms)):
        combined_mms[i] = all_mms[i]

    # convert momemnts to ellipticity estimates
    ells = fpfs.catalog.fpfs_m2e(combined_mms, const=2000)
    resp = np.average(ells['fpfs_R1E'])
    shear = np.average(ells['fpfs_e1'])/resp

    return shear

# %%
rcut = 16

psf_arr = TotPSF.shift(0.5*scale, 0.5*scale).drawImage(nx=rcut*2, ny=rcut*2, scale=scale).array

# inner radius shear mesaurement
inner_shear = detect_and_measure(0.52, psf_arr, gal_sample_cancelled[:4])
print('%1.6e'%inner_shear)
print('error = %1.6e'%(inner_shear - true_shear))

# outer radius shear mesaurement
outer_shear = detect_and_measure(0.7, psf_arr, gal_sample_cancelled[:4])
print('%1.6e'%outer_shear)
print('error = %1.6e'%(outer_shear - true_shear))
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# 100%|██████████| 4/4 [00:00<00:00,  7.91it/s]
# 1.999718e-02
# error = -2.823192e-06
# 100%|██████████| 4/4 [00:00<00:00,  8.01it/s]
# 1.999658e-02
# error = -3.418757e-06

# %% [markdown]
# ## Final test: Add IA shear and see how we perform
# -

# %%
from scipy.signal import convolve2d

def align_and_convolve(gal, gal_ind, psf, A=0.00136207, phi=0, beta=0.82404653, method='scipy', nn=64, scale=0.168):
    '''
    Uses FPFS centering convention, so galaxies do not need to be shifted
    prior to measurement with FPFS!
    '''
    # get details of galaxy half light radius
    rec = cosmos.getParametricRecord(index=gal_ind)
    if rec['use_bulgefit'].astype(bool):
        hlr = rec['hlr'][2]
    else:
        hlr = rec['hlr'][0]
    
    # initialise IA transform object
    IaTransform = batsim.transforms.IaTransform(scale=scale,
                                                hlr=hlr,
                                                A=A, 
                                                phi=phi,
                                                beta=beta,
                                                center=None
                                                )

    # Create and transform stamp object to draw image to
    stamp = batsim.stamp.Stamp(nn=nn, scale=scale, centering='fpfs')
    stamp.transform_grids(IaTransform)
    
    # sample galaxy to stamp
    gal_ia = stamp.sample_galaxy(gal)

    if method=='scipy':
        # convolve with PSF
        psf_arr = psf.shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale, method='auto').array
        psf_arr /= np.sum(psf_arr)

        # Convolution of the galaxy with the PSF
        conv_arr = convolve2d(gal_ia, psf_arr, mode='same')
        conv_im = galsim.Image(conv_arr, scale=scale).bin(upscale, upscale).array
        return conv_im
    elif method=='galsim':
        conv_obj = batsim.stamp.interp_and_convolve(gal_ia, psf, scale=scale)
        return conv_obj
    else:
        raise ValueError('method must be "scipy" or "galsim"')

# %%
nrot = 4
nn = 64
scale = 0.168

Aia_e = 0.02
Aia_g = galsim.Shear(e1=Aia_e).g1
print(Aia_g)

i = 14
gal = gal_sample[i]
gal_ind = gal_inds[i]

simscale = gal.nyquist_scale
simnn = gal.getGoodImageSize(simscale)
print(simscale, simnn)

rotated_gals = cancel_shape_noise(gal, nrot=nrot)
ia_gals = [align_and_convolve(gal=rotg, 
                                gal_ind=gal_ind,
                                psf=TotPSF, 
                                A=0.02, 
                                beta=0.,
                                method='galsim',
                                nn=simnn,
                                scale=simscale,
                                ) for rotg in rotated_gals]

ia_gals = [iag.drawImage(nx=nn, ny=nn, scale=scale, method='auto').array for iag in ia_gals]

shear_gals = [rotg.shear(g1=Aia_g) for rotg in rotated_gals]
conv_gals = [galsim.Convolve([shearg, TotPSF]) for shearg in shear_gals]
for i in range(4):
    plt.subplot(1, 4, i+1)
    resi = ia_gals[i] - conv_gals[i].shift(0.5*simscale, 0.5*simscale).drawImage(nx=nn, ny=nn, scale=scale, method='auto').array
    plt.imshow(resi)
    plt.axis('off')
    plt.title('Rotation %d'%(i+1))
plt.colorbar()
# Out:
# 0.010001000200050014
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 11
#       9 i = 14
#      10 gal = gal_sample[i]
# ---> 11 gal_ind = gal_inds[i]
#      13 simscale = gal.nyquist_scale
#      14 simnn = gal.getGoodImageSize(simscale)
#
# NameError: name 'gal_inds' is not defined

# %%
rcut = 16

psf_arr = TotPSF.shift(0.5*scale, 0.5*scale).drawImage(nx=rcut*2, ny=rcut*2, scale=scale).array

# initialize FPFS shear measurement task
fpTask = fpfs.image.measure_source(psf_arr, sigma_arcsec=0.5, pix_scale=scale)

p1 = nn //2 - rcut
p2 = nn //2 - rcut
psf_arr_pad = np.pad(psf_arr, ((p1, p1), (p2, p2)))

# calculate shear for galsim convolution
all_mms = []
for i in trange(4):
    gal_arr = conv_gals[i].shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale).array
    coords = fpTask.detect_sources(gal_arr,psf_arr_pad,thres=0.01,thres2=-0.00)

    # measure shear with FPFS on individual galaxies
    mms = fpTask.measure(gal_arr, coords)
    mms = fpTask.get_results(mms)
    all_mms.append(mms)

# combine all FPFS moments into single recarray
combined_mms = np.recarray((len(all_mms)), dtype=all_mms[0].dtype)
for i in range(len(all_mms)):
    combined_mms[i] = all_mms[i]

# convert momemnts to ellipticity estimates
ells = fpfs.catalog.fpfs_m2e(combined_mms, const=2000)
resp = np.average(ells['fpfs_R1E'])
shear = np.average(ells['fpfs_e1'])/resp
print('%1.6e'%shear)
print('perc error = %1.6f'%((shear - Aia_g)/Aia_g *100))

rcut = 16

psf_arr = TotPSF.shift(0.5*simscale, 0.5*simscale).drawImage(nx=rcut*2, ny=rcut*2, scale=scale).array

# initialize FPFS shear measurement task
fpTask = fpfs.image.measure_source(psf_arr, sigma_arcsec=0.5, pix_scale=scale)

p1 = nn //2 - rcut
p2 = nn //2 - rcut
psf_arr_pad = np.pad(psf_arr, ((p1, p1), (p2, p2)))

# calculate shear array level BATSim convolution
all_mms = []
for i in trange(4):
    gal_arr = ia_gals[i]
    coords = fpTask.detect_sources(gal_arr,psf_arr_pad,thres=0.01,thres2=-0.00)

    # measure shear with FPFS on individual galaxies
    mms = fpTask.measure(gal_arr, coords)
    mms = fpTask.get_results(mms)
    all_mms.append(mms)
combined_mms = rfn.stack_arrays(all_mms, usemask=False, asrecarray=True)

# convert momemnts to ellipticity estimates
ells = fpfs.catalog.fpfs_m2e(combined_mms, const=2000)
resp = np.average(ells['fpfs_R1E'])
shear = np.average(ells['fpfs_e1'])/resp

print('%1.6e'%shear)
print('perc error = %1.6f'%((shear - Aia_g)/Aia_g * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 rcut = 16
# ----> 3 psf_arr = TotPSF.shift(0.5*scale, 0.5*scale).drawImage(nx=rcut*2, ny=rcut*2, scale=scale).array
#       5 # initialize FPFS shear measurement task
#       6 fpTask = fpfs.image.measure_source(psf_arr, sigma_arcsec=0.5, pix_scale=scale)
#
# NameError: name 'TotPSF' is not defined

# %%
rng = galsim.BaseDeviate(14)
nn = 64
scale = 0.168
nrot = 4

Aia_e = 0.02
Aia_g = galsim.Shear(e1=Aia_e).g1
print(Aia_g)

bigfft = galsim.GSParams(maximum_fft_size=40000)  # galsim setup

if ngal % nrot != 0:
    raise ValueError('ngal/nrot must be an integer')

galsim_sample = [] 
for gal in tqdm(gal_sample):
    rotated_gals = cancel_shape_noise(gal, nrot=4)
    shear_gals = [rotg.shear(g1=Aia_g) for rotg in rotated_gals]
    conv_gals = [galsim.Convolve([shearg, TotPSF]) for shearg in shear_gals]
    arr_gals = [convg.shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale).array for convg in conv_gals]
    [galsim_sample.append(arrg) for arrg in arr_gals]

# batsim_scipy_sample = []
# for i in trange(len(gal_sample)):
#     rotated_gals = cancel_shape_noise(gal_sample[i], nrot=4)
#     gal_ind = gal_inds[i]
#     conv_gals = []
#     for rotg in rotated_gals:
#         conv_gals.append(align_and_convolve(gal=rotg, 
#                                             gal_ind=gal_ind, 
#                                             psf=TotPSF, 
#                                             A=Aia_e, 
#                                             beta=0.,
#                                             method='scipy',
#                                             nn=nn,
#                                             scale=scale
#                                             ))
#     [batsim_scipy_sample.append(convg) for convg in conv_gals]

batsim_galsim_sample = []
simscales = []
for i in trange(len(gal_sample)):
    simscale = gal_sample[i].nyquist_scale
    simnn = gal_sample[i].getGoodImageSize(simscale)
    

    rotated_gals = cancel_shape_noise(gal_sample[i], nrot=4)
    gal_ind = gal_inds[i]
    conv_gals = []
    for rotg in rotated_gals:
        conv_gals.append(align_and_convolve(gal=rotg, 
                                            gal_ind=gal_ind, 
                                            psf=TotPSF, 
                                            A=Aia_e, 
                                            beta=0.,
                                            method='galsim',
                                            nn=simnn,
                                            scale=simscale
                                            ))
        simscales.append(simscale)
    [batsim_galsim_sample.append(convg) for convg in conv_gals]
# Out:
# 0.010001000200050014
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 151.86it/s]
#  12%|█▏        | 3/25 [01:20<09:49, 26.79s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[115], line 49
#      47 conv_gals = []
#      48 for rotg in rotated_gals:
# ---> 49     conv_gals.append(align_and_convolve(gal=rotg,
#      50                                         gal_ind=gal_ind,
#      51                                         psf=TotPSF,
#      52                                         A=Aia_e,
#      53                                         beta=0.,
#      54                                         method='galsim',
#      55                                         nn=simnn,
#      56                                         scale=simscale
#      57                                         ))
#      58     simscales.append(simscale)
#      59 [batsim_galsim_sample.append(convg) for convg in conv_gals]
#
# Cell In[58], line 29, in align_and_convolve(gal, gal_ind, psf, A, phi, beta, method, nn, scale)
#      26 stamp.transform_grids(IaTransform)
#      28 # sample galaxy to stamp
# ---> 29 gal_ia = stamp.sample_galaxy(gal)
#      31 if method=='scipy':
#      32     # convolve with PSF
#      33     psf_arr = psf.shift(0.5*scale, 0.5*scale).drawImage(nx=nn, ny=nn, scale=scale, method='auto').array
#
# File ~/FPFS-project/BATSim/src/batsim/stamp.py:50, in Stamp.sample_galaxy(self, gal_obj)
#      39 def sample_galaxy(self, gal_obj):
#      40     """Sample the surface density field of a galaxy at the grids
#      41     This function only conduct sampling; PSF and pixel response are
#      42     not included.
#    (...)
#      47         outcome (ndarray):  2D galaxy image on the grids
#      48     """
# ---> 50     pixel_values = np.array([gal_obj.xValue(cc + self.centering) for cc in self.coords.T])
#      52     return np.reshape(pixel_values, self.shape)
#
# File ~/FPFS-project/BATSim/src/batsim/stamp.py:50, in <listcomp>(.0)
#      39 def sample_galaxy(self, gal_obj):
#      40     """Sample the surface density field of a galaxy at the grids
#      41     This function only conduct sampling; PSF and pixel response are
#      42     not included.
#    (...)
#      47         outcome (ndarray):  2D galaxy image on the grids
#      48     """
# ---> 50     pixel_values = np.array([gal_obj.xValue(cc + self.centering) for cc in self.coords.T])
#      52     return np.reshape(pixel_values, self.shape)
#
# File ~/miniconda3/envs/FPFS-BATSim/lib/python3.11/site-packages/galsim/gsobject.py:720, in GSObject.xValue(self, *args, **kwargs)
#     694 """Returns the value of the object at a chosen 2D position in real space.
#     695
#     696 This function returns the surface brightness of the object at a particular position
#    (...)
#     717     the surface brightness at that position.
#     718 """
#     719 pos = parse_pos_args(args,kwargs,'x','y')
# --> 720 return self._xValue(pos)
#
# File ~/miniconda3/envs/FPFS-BATSim/lib/python3.11/site-packages/galsim/transform.py:564, in Transformation._xValue(self, pos)
#     562 x = pos.x - self._dx
#     563 y = pos.y - self._dy
# --> 564 inv_pos = _PositionD(*self._inv(x, y))
#     565 return self._original._xValue(inv_pos) * self._amp_scaling
#
# File ~/miniconda3/envs/FPFS-BATSim/lib/python3.11/site-packages/galsim/position.py:242, in _PositionD(x, y)
#     238 """Equivalent to `PositionD` constructor, but skips some sanity checks and argument parsing.
#     239 This requires that x,y are floats.
#     240 """
#     241 ret = PositionD.__new__(PositionD)
# --> 242 ret.x = float(x)
#     243 ret.y = float(y)
#     244 return ret
#
# KeyboardInterrupt:

# %%
def test_kernel_size(sigma_arcsec, psf_arr, gal_arr_list, scale):

    # initialize FPFS shear measurement task
    fpTask = fpfs.image.measure_source(psf_arr, sigma_arcsec=sigma_arcsec, pix_scale=scale)

    p1 = nn //2 - rcut
    p2 = nn //2 - rcut
    psf_arr_pad = np.pad(psf_arr, ((p1, p1), (p2, p2)))

    all_mms = []
    for gal_arr in tqdm(gal_arr_list):
        coords = fpTask.detect_sources(gal_arr,psf_arr_pad,thres=0.01,thres2=-0.00,)

        # measure shear with FPFS on individual galaxies
        mms = fpTask.measure(gal_arr, coords)
        mms = fpTask.get_results(mms)
        all_mms.append(mms)
    combined_mms = rfn.stack_arrays(all_mms, usemask=False, asrecarray=True)

    # convert momemnts to ellipticity estimates
    ells = fpfs.catalog.fpfs_m2e(combined_mms, const=2000)
    resp = np.average(ells['fpfs_R1E'])
    shear = np.average(ells['fpfs_e1'])/resp
    shear_err = np.std(ells["fpfs_e1"]) / np.abs(resp) / np.sqrt(ngal)

    return shear, shear_err

# %%
rcut = 16

psf_arr = TotPSF.shift(0.5*scale, 0.5*scale).drawImage(nx=rcut*2, ny=rcut*2, scale=scale).array

shear, shear_err = test_kernel_size(0.3, psf_arr, galsim_sample, scale=scale)
print('%1.6e'%shear)
print('error = %1.6f'%shear_err)
print('bias = %1.6f'%((shear - Aia_g)/Aia_g * 100))
thresh = max(2.0 * shear_err, 1e-5)
assert np.all(np.abs(shear - Aia_g) < thresh)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.38it/s]
# 9.971858e-03
# error = 0.124271
# bias = -0.291397

# %%
rcut = 16

all_mms = []
for i in trange(len(batsim_galsim_sample)):
    simscale = simscales[i]
    psf_arr = TotPSF.shift(0.5*simscale, 0.5*simscale).drawImage(nx=rcut*2, ny=rcut*2, scale=scale).array
     # initialize FPFS shear measurement task
    fpTask = fpfs.image.measure_source(psf_arr, sigma_arcsec=0.7, pix_scale=scale)
    p1 = nn //2 - rcut
    p2 = nn //2 - rcut
    psf_arr_pad = np.pad(psf_arr, ((p1, p1), (p2, p2)))
    
    gal_arr = batsim_galsim_sample[i].drawImage(nx=nn, ny=nn, scale=scale, method='auto').array
    coords = fpTask.detect_sources(gal_arr,psf_arr_pad,thres=0.01,thres2=-0.00,)
    # measure shear with FPFS on individual galaxies
    mms = fpTask.measure(gal_arr, coords)
    mms = fpTask.get_results(mms)
    all_mms.append(mms)

combined_mms = rfn.stack_arrays(all_mms, usemask=False, asrecarray=True)

# convert momemnts to ellipticity estimates
ells = fpfs.catalog.fpfs_m2e(combined_mms, const=2000)
resp = np.average(ells['fpfs_R1E'])
shear = np.average(ells['fpfs_e1'])/resp
shear_err = np.std(ells["fpfs_e1"]) / np.abs(resp) / np.sqrt(ngal)

print('%1.6e'%shear)
print('error = %1.6f'%shear_err)
print('perc bias = %1.6f'%((shear - Aia_g)/Aia_g * 100))
thresh = max(2.0 * shear_err, 1e-5)
assert np.all(np.abs(shear - Aia_g) < thresh)
# Out:
#   1%|          | 1/100 [00:00<00:16,  5.94it/s]
# 0.06309214883287534
# 0.06309214883287534
#   3%|▎         | 3/100 [00:00<00:15,  6.35it/s]
# 0.06309214883287534
# 0.06309214883287534
#   5%|▌         | 5/100 [00:00<00:14,  6.44it/s]
# 0.06309214883287534
# 0.06309214883287534
#   7%|▋         | 7/100 [00:01<00:14,  6.46it/s]
# 0.06309214883287534
# 0.06309214883287534
#   9%|▉         | 9/100 [00:01<00:14,  6.44it/s]
# 0.06309214883287534
# 0.06309214883287534
#  11%|█         | 11/100 [00:01<00:13,  6.38it/s]
# 0.06309214883287534
# 0.06309214883287534
#  13%|█▎        | 13/100 [00:02<00:13,  6.41it/s]
# 0.06309214883287534
# 0.06309214883287534
#  15%|█▌        | 15/100 [00:02<00:13,  6.38it/s]
# 0.06309214883287534
# 0.06309214883287534
#  17%|█▋        | 17/100 [00:02<00:13,  6.29it/s]
# 0.06309214883287534
# 0.06309214883287534
#  19%|█▉        | 19/100 [00:02<00:12,  6.29it/s]
# 0.06309214883287534
# 0.06309214883287534
#  21%|██        | 21/100 [00:03<00:12,  6.28it/s]
# 0.06309214883287534
# 0.06309214883287534
#  23%|██▎       | 23/100 [00:03<00:12,  6.32it/s]
# 0.06309214883287534
# 0.06309214883287534
#  25%|██▌       | 25/100 [00:03<00:11,  6.32it/s]
# 0.06309214883287534
# 0.06309214883287534
#  27%|██▋       | 27/100 [00:04<00:11,  6.32it/s]
# 0.06309214883287534
# 0.06309214883287534
#  29%|██▉       | 29/100 [00:04<00:11,  6.33it/s]
# 0.06309214883287534
# 0.06309214883287534
#  31%|███       | 31/100 [00:04<00:10,  6.31it/s]
# 0.06309214883287534
# 0.06309214883287534
#  33%|███▎      | 33/100 [00:05<00:10,  6.30it/s]
# 0.06309214883287534
# 0.06309214883287534
#  35%|███▌      | 35/100 [00:05<00:10,  6.32it/s]
# 0.06309214883287534
# 0.06309214883287534
#  36%|███▌      | 36/100 [00:05<00:10,  6.31it/s]
# 0.06309214883287534
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[113], line 18
#      16 coords = fpTask.detect_sources(gal_arr,psf_arr_pad,thres=0.01,thres2=-0.00,)
#      17 # measure shear with FPFS on individual galaxies
# ---> 18 mms = fpTask.measure(gal_arr, coords)
#      19 mms = fpTask.get_results(mms)
#      20 all_mms.append(mms)
#
# File ~/FPFS-project/FPFS/fpfs/image.py:439, in measure_source.measure(self, exposure, coords)
#     437 coords = jnp.atleast_2d(coords.T).T
#     438 func = lambda xi: self.measure_coord(xi, jnp.array(exposure))
# --> 439 return jax.lax.map(func, coords)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/lax/control_flow/loops.py:1984, in map(f, xs)
#    1957 """Map a function over leading array axes.
#    1958
#    1959 Like Python's builtin map, except inputs and outputs are in the form of
#    (...)
#    1981   Mapped values.
#    1982 """
#    1983 g = lambda _, x: ((), f(x))
# -> 1984 _, ys = scan(g, (), xs)
#    1985 return ys
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/lax/control_flow/loops.py:253, in scan(f, init, xs, length, reverse, unroll)
#     246   return init_flat, carry_avals, carry_avals_out, init_tree, in_flat, jaxpr, consts, out_tree, out_tree_children
#     248 # The carry input and output avals must match exactly. However, we want to account for
#     249 # the case when init contains weakly-typed values (e.g. Python scalars), with avals that
#     250 # may not match the output despite being compatible by virtue of their weak type.
#     251 # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#     252 # necessary, a second time with modified init values.
# --> 253 init_flat, carry_avals, carry_avals_out, init_tree, *rest = _create_jaxpr(init)
#     254 new_init_flat, changed = _promote_weak_typed_inputs(init_flat, carry_avals, carry_avals_out)
#     255 if changed:
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/lax/control_flow/loops.py:239, in scan.<locals>._create_jaxpr(init)
#     236 in_flat, in_tree = tree_flatten((init, xs))
#     238 carry_avals = tuple(_map(_abstractify, init_flat))
# --> 239 jaxpr, consts, out_tree = _initial_style_jaxpr(
#     240     f, in_tree, (*carry_avals, *x_avals), "scan")
#     241 out_tree_children = out_tree.children()
#     242 if len(out_tree_children) != 2:
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/lax/control_flow/common.py:65, in _initial_style_jaxpr(fun, in_tree, in_avals, primitive_name)
#      62 @weakref_lru_cache
#      63 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals,
#      64                          primitive_name: Optional[str] = None):
# ---> 65   jaxpr, consts, out_tree = _initial_style_open_jaxpr(
#      66       fun, in_tree, in_avals, primitive_name)
#      67   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#      68   return closed_jaxpr, consts, out_tree
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/lax/control_flow/common.py:59, in _initial_style_open_jaxpr(fun, in_tree, in_avals, primitive_name)
#      56 wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
#      57 debug = pe.debug_info(fun, in_tree, out_tree, False,
#      58                       primitive_name or "<unknown>")
# ---> 59 jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals, debug)
#      60 return jaxpr, consts, out_tree()
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2283, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2281 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2282   main.jaxpr_stack = ()  # type: ignore
# -> 2283   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2284     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2285   del main, fun
#    2286 return jaxpr, out_avals, consts
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2305, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2303 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2304 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2305 ans = fun.call_wrapped(*in_tracers_)
#    2306 out_tracers = map(trace.full_raise, ans)
#    2307 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/lax/control_flow/loops.py:1983, in map.<locals>.<lambda>(_, x)
#    1955 @api_boundary
#    1956 def map(f, xs):
#    1957   """Map a function over leading array axes.
#    1958
#    1959   Like Python's builtin map, except inputs and outputs are in the form of
#    (...)
#    1981     Mapped values.
#    1982   """
# -> 1983   g = lambda _, x: ((), f(x))
#    1984   _, ys = scan(g, (), xs)
#    1985   return ys
#
# File ~/FPFS-project/FPFS/fpfs/image.py:438, in measure_source.measure.<locals>.<lambda>(xi)
#     436     coords = jnp.array(exposure.shape) // 2
#     437 coords = jnp.atleast_2d(coords.T).T
# --> 438 func = lambda xi: self.measure_coord(xi, jnp.array(exposure))
#     439 return jax.lax.map(func, coords)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:255, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     253 @api_boundary
#     254 def cache_miss(*args, **kwargs):
# --> 255   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     256       fun, infer_params_fn, *args, **kwargs)
#     257   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     258   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:161, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     160 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):
# --> 161   args_flat, _, params, in_tree, out_tree, _, _, _ = infer_params_fn(
#     162       *args, **kwargs)
#     163   for arg in args_flat:
#     164     dispatch.check_arg(arg)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/api.py:317, in jit.<locals>.infer_params(*args, **kwargs)
#     308 out_layouts = kwargs.pop('_out_layouts', None)
#     309 pjit_info_args = pjit.PjitInfo(
#     310     fun=fun, in_shardings=in_shardings,
#     311     out_shardings=out_shardings, static_argnums=static_argnums,
#    (...)
#     315     abstracted_axes=abstracted_axes, in_layouts=in_layouts,
#     316     out_layouts=out_layouts)
# --> 317 return pjit.common_infer_params(pjit_info_args, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:491, in common_infer_params(***failed resolving arguments***)
#     485   in_type = in_avals = tuple(avals)
#     487 canonicalized_in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     488     hashable_pytree(in_shardings), hashable_pytree(in_layouts), in_avals,
#     489     in_tree, resource_env, dbg, device_or_backend_set)
# --> 491 jaxpr, consts, canonicalized_out_shardings_flat, out_layouts_flat = _pjit_jaxpr(
#     492     flat_fun, hashable_pytree(out_shardings), hashable_pytree(out_layouts),
#     493     in_type, dbg, device_or_backend_set, HashableFunction(out_tree, closure=()),
#     494     HashableFunction(res_paths, closure=()))
#     496 assert len(explicit_args) == len(canonicalized_in_shardings_flat) == len(in_layouts_flat)
#     498 if config.dynamic_shapes.value:
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:989, in _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info, device_or_backend_set, out_tree, result_paths)
#     987 def _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info,
#     988                 device_or_backend_set, out_tree, result_paths):
# --> 989   jaxpr, final_consts, out_type = _create_pjit_jaxpr(
#     990       fun, in_type, debug_info, result_paths)
#     991   canonicalized_out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#     992       out_shardings_thunk, out_layouts_thunk, out_tree, tuple(out_type),
#     993       jaxpr.jaxpr.debug_info, device_or_backend_set)
#     994   # lu.cache needs to be able to create weakrefs to outputs, so we can't return a plain tuple
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/linear_util.py:349, in cache.<locals>.memoized_fun(fun, *args)
#     347   fun.populate_stores(stores)
#     348 else:
# --> 349   ans = call(fun, *args)
#     350   cache[key] = (ans, fun.stores)
#     352 return ans
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:934, in _create_pjit_jaxpr(fun, in_type, debug_info, out_paths)
#     931     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic2(
#     932         lu.annotate(fun, in_type), debug_info=pe_debug)
#     933   else:
# --> 934     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(
#     935         fun, in_type, debug_info=pe_debug)
#     937 if not config.dynamic_shapes.value:
#     938   jaxpr = jaxpr_debug_info(jaxpr, debug_info, out_paths())
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2283, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2281 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2282   main.jaxpr_stack = ()  # type: ignore
# -> 2283   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2284     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2285   del main, fun
#    2286 return jaxpr, out_avals, consts
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2305, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2303 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2304 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2305 ans = fun.call_wrapped(*in_tracers_)
#    2306 out_tracers = map(trace.full_raise, ans)
#    2307 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/FPFS-project/FPFS/fpfs/image.py:456, in measure_source.measure_coord(self, cc, image)
#     443 """Measures the FPFS moments from a coordinate (jitted)
#     444
#     445 Args:
#    (...)
#     449     mm (ndarray):       FPFS moments
#     450 """
#     451 stamp = jax.lax.dynamic_slice(
#     452     image,
#     453     (cc[0] - self.ngrid // 2, cc[1] - self.ngrid // 2),
#     454     (self.ngrid, self.ngrid),
#     455 )
# --> 456 return self.measure_stamp(stamp)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:255, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     253 @api_boundary
#     254 def cache_miss(*args, **kwargs):
# --> 255   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     256       fun, infer_params_fn, *args, **kwargs)
#     257   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     258   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:161, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     160 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):
# --> 161   args_flat, _, params, in_tree, out_tree, _, _, _ = infer_params_fn(
#     162       *args, **kwargs)
#     163   for arg in args_flat:
#     164     dispatch.check_arg(arg)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/api.py:317, in jit.<locals>.infer_params(*args, **kwargs)
#     308 out_layouts = kwargs.pop('_out_layouts', None)
#     309 pjit_info_args = pjit.PjitInfo(
#     310     fun=fun, in_shardings=in_shardings,
#     311     out_shardings=out_shardings, static_argnums=static_argnums,
#    (...)
#     315     abstracted_axes=abstracted_axes, in_layouts=in_layouts,
#     316     out_layouts=out_layouts)
# --> 317 return pjit.common_infer_params(pjit_info_args, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:491, in common_infer_params(***failed resolving arguments***)
#     485   in_type = in_avals = tuple(avals)
#     487 canonicalized_in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     488     hashable_pytree(in_shardings), hashable_pytree(in_layouts), in_avals,
#     489     in_tree, resource_env, dbg, device_or_backend_set)
# --> 491 jaxpr, consts, canonicalized_out_shardings_flat, out_layouts_flat = _pjit_jaxpr(
#     492     flat_fun, hashable_pytree(out_shardings), hashable_pytree(out_layouts),
#     493     in_type, dbg, device_or_backend_set, HashableFunction(out_tree, closure=()),
#     494     HashableFunction(res_paths, closure=()))
#     496 assert len(explicit_args) == len(canonicalized_in_shardings_flat) == len(in_layouts_flat)
#     498 if config.dynamic_shapes.value:
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:989, in _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info, device_or_backend_set, out_tree, result_paths)
#     987 def _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info,
#     988                 device_or_backend_set, out_tree, result_paths):
# --> 989   jaxpr, final_consts, out_type = _create_pjit_jaxpr(
#     990       fun, in_type, debug_info, result_paths)
#     991   canonicalized_out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#     992       out_shardings_thunk, out_layouts_thunk, out_tree, tuple(out_type),
#     993       jaxpr.jaxpr.debug_info, device_or_backend_set)
#     994   # lu.cache needs to be able to create weakrefs to outputs, so we can't return a plain tuple
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/linear_util.py:349, in cache.<locals>.memoized_fun(fun, *args)
#     347   fun.populate_stores(stores)
#     348 else:
# --> 349   ans = call(fun, *args)
#     350   cache[key] = (ans, fun.stores)
#     352 return ans
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:934, in _create_pjit_jaxpr(fun, in_type, debug_info, out_paths)
#     931     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic2(
#     932         lu.annotate(fun, in_type), debug_info=pe_debug)
#     933   else:
# --> 934     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(
#     935         fun, in_type, debug_info=pe_debug)
#     937 if not config.dynamic_shapes.value:
#     938   jaxpr = jaxpr_debug_info(jaxpr, debug_info, out_paths())
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2283, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2281 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2282   main.jaxpr_stack = ()  # type: ignore
# -> 2283   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2284     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2285   del main, fun
#    2286 return jaxpr, out_avals, consts
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2305, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2303 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2304 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2305 ans = fun.call_wrapped(*in_tracers_)
#    2306 out_tracers = map(trace.full_raise, ans)
#    2307 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/FPFS-project/FPFS/fpfs/image.py:468, in measure_source.measure_stamp(self, data)
#     460 """Measures the FPFS moments from a stamp (jitted)
#     461
#     462 Args:
#    (...)
#     465     mm (ndarray):       FPFS moments
#     466 """
#     467 gal_fourier = jnp.fft.fftshift(jnp.fft.fft2(data))
# --> 468 gal_deconv = self.deconvolve(gal_fourier, prder=0.0, frder=1)
#     469 mm = self._itransform_chi(gal_deconv)  # FPFS shapelets
#     470 mp = self._itransform_psi(gal_deconv)  # FPFS detection
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:255, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     253 @api_boundary
#     254 def cache_miss(*args, **kwargs):
# --> 255   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     256       fun, infer_params_fn, *args, **kwargs)
#     257   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     258   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:161, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     160 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):
# --> 161   args_flat, _, params, in_tree, out_tree, _, _, _ = infer_params_fn(
#     162       *args, **kwargs)
#     163   for arg in args_flat:
#     164     dispatch.check_arg(arg)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/api.py:317, in jit.<locals>.infer_params(*args, **kwargs)
#     308 out_layouts = kwargs.pop('_out_layouts', None)
#     309 pjit_info_args = pjit.PjitInfo(
#     310     fun=fun, in_shardings=in_shardings,
#     311     out_shardings=out_shardings, static_argnums=static_argnums,
#    (...)
#     315     abstracted_axes=abstracted_axes, in_layouts=in_layouts,
#     316     out_layouts=out_layouts)
# --> 317 return pjit.common_infer_params(pjit_info_args, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:491, in common_infer_params(***failed resolving arguments***)
#     485   in_type = in_avals = tuple(avals)
#     487 canonicalized_in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     488     hashable_pytree(in_shardings), hashable_pytree(in_layouts), in_avals,
#     489     in_tree, resource_env, dbg, device_or_backend_set)
# --> 491 jaxpr, consts, canonicalized_out_shardings_flat, out_layouts_flat = _pjit_jaxpr(
#     492     flat_fun, hashable_pytree(out_shardings), hashable_pytree(out_layouts),
#     493     in_type, dbg, device_or_backend_set, HashableFunction(out_tree, closure=()),
#     494     HashableFunction(res_paths, closure=()))
#     496 assert len(explicit_args) == len(canonicalized_in_shardings_flat) == len(in_layouts_flat)
#     498 if config.dynamic_shapes.value:
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:989, in _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info, device_or_backend_set, out_tree, result_paths)
#     987 def _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info,
#     988                 device_or_backend_set, out_tree, result_paths):
# --> 989   jaxpr, final_consts, out_type = _create_pjit_jaxpr(
#     990       fun, in_type, debug_info, result_paths)
#     991   canonicalized_out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#     992       out_shardings_thunk, out_layouts_thunk, out_tree, tuple(out_type),
#     993       jaxpr.jaxpr.debug_info, device_or_backend_set)
#     994   # lu.cache needs to be able to create weakrefs to outputs, so we can't return a plain tuple
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/linear_util.py:349, in cache.<locals>.memoized_fun(fun, *args)
#     347   fun.populate_stores(stores)
#     348 else:
# --> 349   ans = call(fun, *args)
#     350   cache[key] = (ans, fun.stores)
#     352 return ans
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:934, in _create_pjit_jaxpr(fun, in_type, debug_info, out_paths)
#     931     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic2(
#     932         lu.annotate(fun, in_type), debug_info=pe_debug)
#     933   else:
# --> 934     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(
#     935         fun, in_type, debug_info=pe_debug)
#     937 if not config.dynamic_shapes.value:
#     938   jaxpr = jaxpr_debug_info(jaxpr, debug_info, out_paths())
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2283, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2281 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2282   main.jaxpr_stack = ()  # type: ignore
# -> 2283   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2284     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2285   del main, fun
#    2286 return jaxpr, out_avals, consts
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2305, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2303 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2304 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2305 ans = fun.call_wrapped(*in_tracers_)
#    2306 out_tracers = map(trace.full_raise, ans)
#    2307 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/FPFS-project/FPFS/fpfs/image.py:129, in measure_base.deconvolve(self, data, prder, frder)
#     112 """Deconvolves input data with the PSF or PSF power
#     113
#     114 Args:
#    (...)
#     124         Deconvolved galaxy power [truncated at klim]
#     125 """
#     126 out = jnp.zeros(data.shape, dtype="complex128")
#     127 out2 = out.at[self._ind2d].set(
#     128     data[self._ind2d]
# --> 129     / self.psf_pow[self._ind2d] ** prder
#     130     / self.psf_fourier[self._ind2d] ** frder
#     131 )
#     132 return out2
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/array.py:336, in ArrayImpl.__getitem__(self, idx)
#     334   return lax_numpy._rewriting_take(self, idx)
#     335 else:
# --> 336   return lax_numpy._rewriting_take(self, idx)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:4498, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    4495       return lax.dynamic_index_in_dim(arr, idx, keepdims=False)
#    4497 treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> 4498 return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    4499                unique_indices, mode, fill_value)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:4507, in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    4504 def _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    4505             unique_indices, mode, fill_value):
#    4506   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# -> 4507   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#    4508   y = arr
#    4510   if fill_value is not None:
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:4634, in _index_to_gather(x_shape, idx, normalize_indices)
#    4631   if normalize_indices:
#    4632     advanced_pairs = ((_normalize_index(e, x_shape[j]), i, j)
#    4633                       for e, i, j in advanced_pairs)
# -> 4634   advanced_indexes, idx_advanced_axes, x_advanced_axes = zip(*advanced_pairs)
#    4635   advanced_axes_are_contiguous = bool(np.all(np.diff(idx_advanced_axes) == 1))
#    4637 x_axis = 0  # Current axis in x.
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:4632, in <genexpr>(.0)
#    4628 advanced_pairs = (
#    4629   (asarray(e), i, j) for j, (i, e) in enumerate(idx_no_nones)
#    4630   if isscalar(e) or isinstance(e, (Sequence, Array, np.ndarray)))
#    4631 if normalize_indices:
# -> 4632   advanced_pairs = ((_normalize_index(e, x_shape[j]), i, j)
#    4633                     for e, i, j in advanced_pairs)
#    4634 advanced_indexes, idx_advanced_axes, x_advanced_axes = zip(*advanced_pairs)
#    4635 advanced_axes_are_contiguous = bool(np.all(np.diff(idx_advanced_axes) == 1))
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:4263, in _normalize_index(index, axis_size)
#    4261   return lax.add(index, axis_size_val) if index < 0 else index
#    4262 else:
# -> 4263   return lax.select(index < 0, lax.add(index, axis_size_val), index)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:269, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     267 args = (other, self) if swap else (self, other)
#     268 if isinstance(other, _accepted_binop_types):
# --> 269   return binary_op(*args)
#     270 # Note: don't use isinstance here, because we don't want to raise for
#     271 # subclasses, e.g. NamedTuple objects that may override operators.
#     272 if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:255, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     253 @api_boundary
#     254 def cache_miss(*args, **kwargs):
# --> 255   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     256       fun, infer_params_fn, *args, **kwargs)
#     257   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     258   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:166, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     164   dispatch.check_arg(arg)
#     165 try:
# --> 166   out_flat = pjit_p.bind(*args_flat, **params)
#     167 except pxla.DeviceAssignmentMismatchError as e:
#     168   fails, = e.args
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:2682, in AxisPrimitive.bind(self, *args, **params)
#    2678 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2679                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2680 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2681              else axis_main.with_cur_sublevel())
# -> 2682 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:405, in Primitive.bind_with_trace(self, trace, args, params)
#     404 def bind_with_trace(self, trace, args, params):
# --> 405   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     406   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:1976, in DynamicJaxprTrace.process_primitive(self, primitive, tracers, params)
#    1974 def process_primitive(self, primitive, tracers, params):
#    1975   if primitive in custom_staging_rules:
# -> 1976     return custom_staging_rules[primitive](self, *tracers, **params)
#    1977   return self.default_process_primitive(primitive, tracers, params)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:1349, in pjit_staging_rule(trace, *args, **params)
#    1345 if (params["inline"] and
#    1346     all(is_unspecified(i) for i in params["in_shardings"]) and
#    1347     all(is_unspecified(o) for o in params["out_shardings"])):
#    1348   jaxpr = params['jaxpr']
# -> 1349   return core.eval_jaxpr(jaxpr.jaxpr, jaxpr.consts, *args,
#    1350                          propagate_source_info=False)
#    1351 elif config.dynamic_shapes.value:
#    1352   source_info = source_info_util.current()
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:470, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     468 traceback = eqn.source_info.traceback if propagate_source_info else None
#     469 with source_info_util.user_context(traceback, name_stack=name_stack):
# --> 470   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     471 if eqn.primitive.multiple_results:
#     472   map(write, eqn.outvars, ans)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:402, in Primitive.bind(self, *args, **params)
#     399 def bind(self, *args, **params):
#     400   assert (not config.enable_checks.value or
#     401           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 402   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:1309, in find_top_trace(xs)
#    1306   else:
#    1307     return val
# -> 1309 def find_top_trace(xs) -> Trace:
#    1310   top_tracer = max((x for x in xs if isinstance(x, Tracer)),
#    1311                     default=None, key=attrgetter('_trace.level'))
#    1312   if top_tracer is not None:
#
# KeyboardInterrupt:

# %%
rcut = 16

psf_arr = TotPSF.shift(0.5*scale, 0.5*scale).drawImage(nx=rcut*2, ny=rcut*2, scale=scale).array

kernels = np.linspace(0.3,1.2,20)

galsim_bias = np.empty(len(kernels))
batsim_galsim_bias = np.empty(len(kernels))
batsim_scipy_bias = np.empty(len(kernels))
for i in trange(len(kernels)):
    print(kernels[i])
    galsim_shear, _ = test_kernel_size(kernels[i], psf_arr, galsim_sample)
    galsim_bias[i] = (galsim_shear - Aia_g)/Aia_g *100

    batsim_galsim_shear, _ = test_kernel_size(kernels[i], psf_arr, batsim_galsim_sample)
    batsim_galsim_bias[i] = (batsim_galsim_shear - Aia_g)/Aia_g *100

    # batsim_scipy_shear, _ = test_kernel_size(kernels[i], psf_arr, batsim_scipy_sample)
    # batsim_scipy_bias[i] = (batsim_scipy_shear - Aia_g)/Aia_g *100
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 0.3
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[57], line 12
#      10 for i in trange(len(kernels)):
#      11     print(kernels[i])
# ---> 12     galsim_shear, _ = test_kernel_size(kernels[i], psf_arr, galsim_sample)
#      13     galsim_bias[i] = (galsim_shear - Aia_g)/Aia_g *100
#      15     batsim_galsim_shear, _ = test_kernel_size(kernels[i], psf_arr, batsim_galsim_sample)
#
# Cell In[40], line 12, in test_kernel_size(sigma_arcsec, psf_arr, gal_arr_list)
#      10 all_mms = []
#      11 for gal_arr in tqdm(gal_arr_list):
# ---> 12     coords = fpTask.detect_sources(gal_arr,psf_arr_pad,thres=0.01,thres2=-0.00,)
#      14     # measure shear with FPFS on individual galaxies
#      15     mms = fpTask.measure(gal_arr, coords)
#
# File ~/FPFS-project/FPFS/fpfs/image.py:289, in measure_source.detect_sources(self, img_data, psf_data, thres, thres2, bound)
#     286     raise ValueError("difference threshold should be non-positive")
#     287 psf_data = jnp.array(psf_data, dtype="<f8")
#     288 assert (
# --> 289     img_data.shape == psf_data.shape
#     290 ), "image and PSF should have the same\
#     291         shape. Please do padding before using this function."
#     292 img_conv = imgutil.convolve2gausspsf(
#     293     img_data,
#     294     psf_data,
#     295     self.sigmaf,
#     296     self.klim,
#     297 )
#     298 img_conv_det = imgutil.convolve2gausspsf(
#     299     img_data,
#     300     psf_data,
#     301     self.sigmaf_det,
#     302     self.klim,
#     303 )
#
# AssertionError: image and PSF should have the same                shape. Please do padding before using this function.

# %%
plt.plot(kernels, abs(batsim_scipy_bias), label='BATSim shear, scipy convolution')
plt.plot(kernels, abs(batsim_galsim_bias), label='BATSim shear, Galsim convolution')
plt.plot(kernels, abs(galsim_bias), label='Galsim shear and convolution')
plt.legend()
plt.xlabel('Kernel Size')
plt.ylabel('Percent Bias')
plt.ylim([0,5])
plt.savefig('kernel_size_bias.png', dpi=300)
